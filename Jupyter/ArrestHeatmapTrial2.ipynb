# %% [markdown]
# # UCSB Isla Vista Arrest Heatmaps Trial 2: Counts
#
# This project involves creating heatmaps to visualize arrest patterns in Isla Vista, CA, from September to November 2024, integrating GeoPy with Folium to map and display the data for an article in UCSB's student-run newspaper, the *Daily Nexus*.
#
# ### Project Description
# The goal of this project was to create detailed heatmaps to visualize the spatial distribution and concentration of arrests in Isla Vista, CA, during the early academic months of September to November 2024. The heatmaps were developed to  accompany and enhance an article written in the *Daily Nexus*, UC Santa Barbara's independent, student-run newspaper. The article, "*Substance-related and theft-related arrests rise in Isla Vista over the last two months*", was written by me (Anna Gornyitzki) and Aastha Prakash.
#
# ### Trial 2: Counts
# When creating the initial heatmaps for the project, the visuals effectively represented where arrests in Isla Vista occurred, providing readers with a clear geographic overview. To enhance the visualization further, I plan to include arrest counts directly on the map, giving readers more context about the exact number of arrests at each location.

# %% [markdown]
# # Heatmap 1: All Arrests with Counts

# %% [markdown]
# ## 1. Importing Required Libraries

# %%
import sqlite3
import pandas as pd
from geopy.geocoders import GoogleV3
from geopy.exc import GeocoderTimedOut
import folium
from folium.plugins import HeatMap
import time

# %% [markdown]
# This block imports all the necessary libraries to carry out the task:
# * `sqlite3` for interacting with the SQLite database
# * `pandas` for handling data and manipulating data frames
# * `geopy.geocoders.GoogleV3` to geocode addresses into geographic coordinates (latitude and longitude).
# - `folium` for generating interactive maps.
# - `folium.plugins.HeatMap` for creating heatmaps using folium.
# - `time` for handling time-based operations

# %% [markdown]
# ## 2. Loading Data and Preparing Addresses

# %%
conn = sqlite3.connect('arrestsData.db')
df = pd.read_sql_query('SELECT Location || ", Isla Vista, CA" as address, COUNT(*) AS cc FROM UCSB_Crime_Fire_Log ucfl WHERE Disposition LIKE "Arrest%" GROUP BY address', conn)
addresses = df['address'].tolist()
counts = df['cc'].tolist()
conn.close()

# %% [markdown]
# * Open a connection to the SQLite database `arrestsData.db`.
# * Execute an SQL query to:
#    - Retrieve arrest records grouped by location.
#    - Format locations to include ", Isla Vista, CA".
#    - Count the number of arrests at each location.
# * Store the query results in a pandas DataFrame.
# * Extract the addresses and corresponding arrest counts into separate Python lists.
# * Close the database connection.

# %% [markdown]
# ## 3. Geocoding and Address Cleanup

# %%
geolocator = GoogleV3(api_key="AIzaSyAbuVVnrz3oKEg8NtLahqR3qHOX35tBbHg") 

notFound = []

def geocode_address(address, precision=4):
    try:
        location = geolocator.geocode(address)
        if location:
            # Round latitude and longitude to the specified precision
            latitude = round(location.latitude, precision)
            longitude = round(location.longitude, precision)
            return [latitude, longitude]
        else:
            notFound.append(address)
            return None
    except GeocoderTimedOut:
        return geocode_address(address)
        
def clean_address(address):
     return address

# %% [markdown]
# * **Initialize Geocoder**: Use the Google Maps API (`GoogleV3`) to geocode addresses into geographic coordinates.
# * **Track Missing Addresses**: Create a `notFound` list to store addresses that cannot be geocoded successfully.
# * **Geocoding Function**:
#    - Convert addresses to latitude and longitude with a specified precision (default: 4 decimal places).
#    - Handle timeout errors by retrying the geocoding operation.
# * **Clean Address Function**:
#    - Prepare and normalize addresses by removing unwanted text or simplifying the format.

# %% [markdown]
# ## 4. Generate and Save Coordinates with Counts

# %%
coordinates_with_counts = []
for address, count in zip(addresses, counts):
    coord = geocode_address(clean_address(address))
    if coord:
        coordinates_with_counts.append([coord[0], coord[1], count])

# %% [markdown]
# * Loop through addresses and their arrest counts.
# * Clean and geocode each address to get latitude and longitude.
# * Save valid coordinates with counts to a list and store them in the database.
# * Optionally, pause requests to avoid overloading the geocoding service.

# %% [markdown]
# ## 5. Setting the Map Center and Creating the Heatmap

# %%
map_center = [34.413120041278376, -119.86458253856023]
heat_map = folium.Map(location=map_center, zoom_start=15)

# %% [markdown]
# - The `map_center` is set to the geographic coordinates for a central point in Isla Vista, CA.
# - A `folium.Map` object is created, centered on `map_center` with an initial zoom level of 15.

# %% [markdown]
# ## 6. Add Circle Markers with Counts as Tooltips

# %%
for lat, lon, count in coordinates_with_counts:
    folium.Marker(
            location=[lat, lon],
            icon=folium.DivIcon(html=f"""
                <div style="font-size: 18px; color: blue; font-weight: bold;">
                    {count}
                </div>
            """)
        ).add_to(heat_map)

# %% [markdown]
# - A loop iterates through coordinates_with_counts, which should be a list of tuples containing latitude (lat), longitude (lon), and a count value.
# - For each tuple, a Marker is added to the map at the corresponding location.
# - A custom DivIcon is used to display the count in blue, bold text at the marker's position.

# %% [markdown]
# ## 7. Create Heatmap Data and Layer

# %%
heatmap_data = [[lat, lon, count] for lat, lon, count in coordinates_with_counts]
plugins.HeatMap(heatmap_data).add_to(heat_map)

# %% [markdown]
# - Create a list heatmap_data containing latitude, longitude, and count for each location, which will be used for the heatmap layer.
# - The HeatMap plugin is applied to the heatmap_data, adding a heatmap layer to the map. This visualizes the intensity of the counts at different locations, where the count determines the intensity of the heat.

# %% [markdown]
# ## 8. Saving and Displaying the Map

# %% [markdown]
# The generated heatmap is saved as an HTML file using the `save()` method, allowing it to be viewed in a web browser. The heatmap is then displayed and provides an interactive visualization of arrest concentrations across Isla Vista.

# %%
heat_map.save("generalHeatmapCounts.html")
heat_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8989290f53b61a6d2008d5db9cc8539b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8989290f53b61a6d2008d5db9cc8539b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8989290f53b61a6d2008d5db9cc8539b = L.map(
#                 &quot;map_8989290f53b61a6d2008d5db9cc8539b&quot;,
#                 {
#                     center: [34.413120041278376, -119.86458253856023],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a2db605db3b7e8976b00ca5896089f09 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a2db605db3b7e8976b00ca5896089f09.addTo(map_8989290f53b61a6d2008d5db9cc8539b);
#
#
#             var marker_36f21a841db39176d94f18c5e36fc1db = L.marker(
#                 [34.4093, -119.8538],
#                 {}
#             ).addTo(map_8989290f53b61a6d2008d5db9cc8539b);
#
#
#             var div_icon_09cc7f8fdc012233e374a16e3d254301 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n                \u003cdiv style=\&quot;font-size: 18px; color: blue; font-weight: bold;\&quot;\u003e\n                    9\n                \u003c/div\u003e\n            &quot;});
#             marker_36f21a841db39176d94f18c5e36fc1db.setIcon(div_icon_09cc7f8fdc012233e374a16e3d254301);
#
#
#             var marker_ad86ddc4d524c932bc0580329bd295af = L.marker(
#                 [34.4177, -119.8538],
#                 {}
#             ).addTo(map_8989290f53b61a6d2008d5db9cc8539b);
#
#
#             var div_icon_224f8444dc6980ba9fc4a782d8f986ff = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n                \u003cdiv style=\&quot;font-size: 18px; color: blue; font-weight: bold;\&quot;\u003e\n                    1\n                \u003c/div\u003e\n            &quot;});
#             marker_ad86ddc4d524c932bc0580329bd295af.setIcon(div_icon_224f8444dc6980ba9fc4a782d8f986ff);
#
#
#             var marker_5434f3cca9d61e50efde938a772611d2 = L.marker(
#                 [34.4106, -119.8541],
#                 {}
#             ).addTo(map_8989290f53b61a6d2008d5db9cc8539b);
#
#
#             var div_icon_0352ce8bb5cdb14fa62cfc2169b42eca = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n                \u003cdiv style=\&quot;font-size: 18px; color: blue; font-weight: bold;\&quot;\u003e\n                    1\n                \u003c/div\u003e\n            &quot;});
#             marker_5434f3cca9d61e50efde938a772611d2.setIcon(div_icon_0352ce8bb5cdb14fa62cfc2169b42eca);
#
#
#             var marker_f3331e1957ebd400e83488f4ccee7531 = L.marker(
#                 [34.412, -119.8539],
#                 {}
#             ).addTo(map_8989290f53b61a6d2008d5db9cc8539b);
#
#
#             var div_icon_63ba60d90b4694a90eed4eaa1aa44559 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n                \u003cdiv style=\&quot;font-size: 18px; color: blue; font-weight: bold;\&quot;\u003e\n                    1\n                \u003c/div\u003e\n            &quot;});
#             marker_f3331e1957ebd400e83488f4ccee7531.setIcon(div_icon_63ba60d90b4694a90eed4eaa1aa44559);
#
#
#             var marker_fa9b17d33110a599aef25ef7cbfe4517 = L.marker(
#                 [34.4113, -119.8538],
#                 {}
#             ).addTo(map_8989290f53b61a6d2008d5db9cc8539b);
#
#
#             var div_icon_84b3015d247c5247d2483d6e00409021 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n                \u003cdiv style=\&quot;font-size: 18px; color: blue; font-weight: bold;\&quot;\u003e\n                    3\n                \u003c/div\u003e\n            &quot;});
#             marker_fa9b17d33110a599aef25ef7cbfe4517.setIcon(div_icon_84b3015d247c5247d2483d6e00409021);
#
#
#             var marker_ddf21922afcc2a7b5627fc64b2d48ac4 = L.marker(
#                 [34.4138, -119.8539],
#                 {}
#             ).addTo(map_8989290f53b61a6d2008d5db9cc8539b);
#
#
#             var div_icon_0cb00e67db6434f2207b41d994b91527 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n                \u003cdiv style=\&quot;font-size: 18px; color: blue; font-weight: bold;\&quot;\u003e\n                    1\n                \u003c/div\u003e\n            &quot;});
#             marker_ddf21922afcc2a7b5627fc64b2d48ac4.setIcon(div_icon_0cb00e67db6434f2207b41d994b91527);
#
#
#             var marker_8e36bb49c0dc7ffef1acc2402eedc846 = L.marker(
#                 [34.4141, -119.8587],
#                 {}
#             ).addTo(map_8989290f53b61a

# %% [markdown]
# # Heatmap 2: Substance-related Arrests

# %% [markdown]
# The same process is repeated for substance-related arrests as was for all arrests except the only difference is the SQL query used.

# %%
import sqlite3
import pandas as pd
from geopy.geocoders import GoogleV3
from geopy.exc import GeocoderTimedOut
import folium
from folium.plugins import HeatMap
import time

conn = sqlite3.connect('arrestsData.db')
df = pd.read_sql_query("SELECT Location || ', Isla Vista, CA' as address, COUNT(*) AS cc FROM UCSB_Crime_Fire_Log ucfl WHERE Disposition LIKE 'Arrest%' AND (upper(Classification) LIKE '%ALCOHOL%' OR upper(Classification) LIKE '%INTOXICATION%' OR upper(Classification) LIKE '%DRUG%' OR upper(Classification) LIKE '%OPEN CONTAINER%' OR upper(Classification) LIKE '%SUBSTANCE%' OR upper(Classification) LIKE '%INFLUENCE%'OR upper(Classification) LIKE '%POSSESS%' OR upper(Classification) LIKE '%NARCOTICS%') GROUP BY address", conn)

# %% [markdown]
# A SQL query is executed to retrieve arrest data for substance-related offenses from the `UCSB_Crime_Fire_Log` table. The query filters rows based on the `Disposition` field (to include only "Arrest" entries) and matches keywords related to substance use (e.g., "ALCOHOL," "DRUG," "INTOXICATION"). It also concatenates `", Isla Vista, CA"` to the `Location` field to form complete addresses.

# %%
addresses = df['address'].tolist()
counts = df['cc'].tolist()
conn.close()

geolocator = GoogleV3(api_key="AIzaSyAbuVVnrz3oKEg8NtLahqR3qHOX35tBbHg") 

notFound = []

def geocode_address(address, precision=4):
    try:
        location = geolocator.geocode(address)
        if location:
            # Round latitude and longitude to the specified precision
            latitude = round(location.latitude, precision)
            longitude = round(location.longitude, precision)
            return [latitude, longitude]
        else:
            notFound.append(address)
            return None
    except GeocoderTimedOut:
        return geocode_address(address)
        
def clean_address(address):
     return address

coordinates_with_counts = []
for address, count in zip(addresses, counts):
    coord = geocode_address(clean_address(address))
    if coord:
        coordinates_with_counts.append([coord[0], coord[1], count])

map_center = [34.413120041278376, -119.86458253856023]
s_heat_map = folium.Map(location=map_center, zoom_start=15)

for lat, lon, count in coordinates_with_counts:
    folium.Marker(
            location=[lat, lon],
            icon=folium.DivIcon(html=f"""
                <div style="font-size: 18px; color: blue; font-weight: bold;">
                    {count}
                </div>
            """)
        ).add_to(s_heat_map)

heatmap_data = [[lat, lon, count] for lat, lon, count in coordinates_with_counts]
plugins.HeatMap(heatmap_data).add_to(s_heat_map)

s_heat_map.save("substanceHeatmapCounts.html")
s_heat_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b2b03201876e5d299de00553c70e4a9e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b2b03201876e5d299de00553c70e4a9e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b2b03201876e5d299de00553c70e4a9e = L.map(
#                 &quot;map_b2b03201876e5d299de00553c70e4a9e&quot;,
#                 {
#                     center: [34.413120041278376, -119.86458253856023],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6448f2b4636b518b505f0c136462182a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6448f2b4636b518b505f0c136462182a.addTo(map_b2b03201876e5d299de00553c70e4a9e);
#
#
#             var marker_87d72a18f10a163d054ade8f9ba125d9 = L.marker(
#                 [34.4093, -119.8538],
#                 {}
#             ).addTo(map_b2b03201876e5d299de00553c70e4a9e);
#
#
#             var div_icon_7ec15694ec5f8ff49421f92c7bcb1c52 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n                \u003cdiv style=\&quot;font-size: 18px; color: blue; font-weight: bold;\&quot;\u003e\n                    9\n                \u003c/div\u003e\n            &quot;});
#             marker_87d72a18f10a163d054ade8f9ba125d9.setIcon(div_icon_7ec15694ec5f8ff49421f92c7bcb1c52);
#
#
#             var marker_2bdb68e29736e77be5b6e84d34f679f1 = L.marker(
#                 [34.4106, -119.8541],
#                 {}
#             ).addTo(map_b2b03201876e5d299de00553c70e4a9e);
#
#
#             var div_icon_98eb66563ecfbf762eb45eb3a59bc5e7 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n                \u003cdiv style=\&quot;font-size: 18px; color: blue; font-weight: bold;\&quot;\u003e\n                    1\n                \u003c/div\u003e\n            &quot;});
#             marker_2bdb68e29736e77be5b6e84d34f679f1.setIcon(div_icon_98eb66563ecfbf762eb45eb3a59bc5e7);
#
#
#             var marker_4e3b352a1d343c3e6197a3b2697f2e3a = L.marker(
#                 [34.4113, -119.8538],
#                 {}
#             ).addTo(map_b2b03201876e5d299de00553c70e4a9e);
#
#
#             var div_icon_b3b54f091d746e239d0a057dab580d97 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n                \u003cdiv style=\&quot;font-size: 18px; color: blue; font-weight: bold;\&quot;\u003e\n                    2\n                \u003c/div\u003e\n            &quot;});
#             marker_4e3b352a1d343c3e6197a3b2697f2e3a.setIcon(div_icon_b3b54f091d746e239d0a057dab580d97);
#
#
#             var marker_c726dafc04d56706ab89af449535cf8a = L.marker(
#                 [34.4138, -119.8539],
#                 {}
#             ).addTo(map_b2b03201876e5d299de00553c70e4a9e);
#
#
#             var div_icon_548d24826ca9f6bd80df5d5e5234452b = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n                \u003cdiv style=\&quot;font-size: 18px; color: blue; font-weight: bold;\&quot;\u003e\n                    1\n                \u003c/div\u003e\n            &quot;});
#             marker_c726dafc04d56706ab89af449535cf8a.setIcon(div_icon_548d24826ca9f6bd80df5d5e5234452b);
#
#
#             var marker_e14ea69d718918d6e17ca9f84879d1a1 = L.marker(
#                 [34.4141, -119.8587],
#                 {}
#             ).addTo(map_b2b03201876e5d299de00553c70e4a9e);
#
#
#             var div_icon_26529abc994629cef924d47ede27da45 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n                \u003cdiv style=\&quot;font-size: 18px; color: blue; font-weight: bold;\&quot;\u003e\n                    1\n                \u003c/div\u003e\n            &quot;});
#             marker_e14ea69d718918d6e17ca9f84879d1a1.setIcon(div_icon_26529abc994629cef924d47ede27da45);
#
#
#             var marker_30494864f436ff34d65c75a9699e8137 = L.marker(
#                 [34.4098, -119.8587],
#                 {}
#             ).addTo(map_b2b03201876e5d299de00553c70e4a9e);
#
#
#             var div_icon_c0287ce851e43402b5f9ff98ac0aaf77 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n                \u003cdiv style=\&quot;font-size: 18px; color: blue; font-weight: bold;\&quot;\u003e\n                    15\n                \u003c/div\u003e\n            &quot;});
#             marker_30494864f436ff34d65c75a9699e8137.setIcon(div_icon_c0287ce851e43402b5f9ff98ac0aaf77);
#
#
#             var marker_2ddfad0beb46b630f0b228382f24c270 = L.marker(
#                 [34.4152, -119.8587],
#                 {}
#             ).addTo(map_b2b03201876e

# %% [markdown]
# # Heatmap 3: Theft and property-related Arrests

# %% [markdown]
# The same process is repeated for theft and property-related arrests as was for all arrests except the only difference is the SQL query used.

# %%
import sqlite3
import pandas as pd
from geopy.geocoders import GoogleV3
from geopy.exc import GeocoderTimedOut
import folium
from folium.plugins import HeatMap
import time

conn = sqlite3.connect('arrestsData.db')
df = pd.read_sql_query("SELECT Location || ', Isla Vista, CA' as address, COUNT(*) AS cc FROM UCSB_Crime_Fire_Log ucfl WHERE Disposition LIKE 'Arrest%' AND (upper(Classification) LIKE '%THEFT%' OR upper(Classification) LIKE '%LARCENY%' OR upper(Classification) LIKE '%SHOPLIFTING%' OR upper(Classification) LIKE '%VANDALISM%' OR upper(Classification) LIKE '%TRESPASS%' OR upper(Classification) LIKE '%PROPERTY%'OR upper(Classification) LIKE '%BURGLARY%') GROUP BY address", conn)

# %% [markdown]
# A SQL query is executed to retrieve arrest data for substance-related offenses from the UCSB_Crime_Fire_Log table. The query filters rows based on the Disposition field (to include only "Arrest" entries) and matches keywords related to theft and property crimes (e.g., "THEFT," "SHOPLIFTING," "BURGLARY"). It also concatenates ", Isla Vista, CA" to the Location field to form complete addresses.

# %%
addresses = df['address'].tolist()
counts = df['cc'].tolist()
conn.close()

geolocator = GoogleV3(api_key="AIzaSyAbuVVnrz3oKEg8NtLahqR3qHOX35tBbHg") 

notFound = []

def geocode_address(address, precision=4):
    try:
        location = geolocator.geocode(address)
        if location:
            # Round latitude and longitude to the specified precision
            latitude = round(location.latitude, precision)
            longitude = round(location.longitude, precision)
            return [latitude, longitude]
        else:
            notFound.append(address)
            return None
    except GeocoderTimedOut:
        return geocode_address(address)
        
def clean_address(address):
     return address

coordinates_with_counts = []
for address, count in zip(addresses, counts):
    coord = geocode_address(clean_address(address))
    if coord:
        coordinates_with_counts.append([coord[0], coord[1], count])

map_center = [34.413120041278376, -119.86458253856023]
t_heat_map = folium.Map(location=map_center, zoom_start=15)

for lat, lon, count in coordinates_with_counts:
    folium.Marker(
            location=[lat, lon],
            icon=folium.DivIcon(html=f"""
                <div style="font-size: 18px; color: blue; font-weight: bold;">
                    {count}
                </div>
            """)
        ).add_to(t_heat_map)

heatmap_data = [[lat, lon, count] for lat, lon, count in coordinates_with_counts]
plugins.HeatMap(heatmap_data).add_to(t_heat_map)

t_heat_map.save("theftHeatmapCounts.html")
t_heat_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_330cef23b271b6564d6d3ed827810ad9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_330cef23b271b6564d6d3ed827810ad9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_330cef23b271b6564d6d3ed827810ad9 = L.map(
#                 &quot;map_330cef23b271b6564d6d3ed827810ad9&quot;,
#                 {
#                     center: [34.413120041278376, -119.86458253856023],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e999170e79d301fed567a7bbe6fa2a83 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e999170e79d301fed567a7bbe6fa2a83.addTo(map_330cef23b271b6564d6d3ed827810ad9);
#
#
#             var marker_68d14f5e17c0890411012909a5470b33 = L.marker(
#                 [34.4177, -119.8538],
#                 {}
#             ).addTo(map_330cef23b271b6564d6d3ed827810ad9);
#
#
#             var div_icon_84d02533fc954dd868cb363fda7b0034 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n                \u003cdiv style=\&quot;font-size: 18px; color: blue; font-weight: bold;\&quot;\u003e\n                    1\n                \u003c/div\u003e\n            &quot;});
#             marker_68d14f5e17c0890411012909a5470b33.setIcon(div_icon_84d02533fc954dd868cb363fda7b0034);
#
#
#             var marker_f1699f68f8c6aadd59fcdbfdf228d988 = L.marker(
#                 [34.4141, -119.8587],
#                 {}
#             ).addTo(map_330cef23b271b6564d6d3ed827810ad9);
#
#
#             var div_icon_b96cd533163cb1d1105100499b5fe0a5 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n                \u003cdiv style=\&quot;font-size: 18px; color: blue; font-weight: bold;\&quot;\u003e\n                    1\n                \u003c/div\u003e\n            &quot;});
#             marker_f1699f68f8c6aadd59fcdbfdf228d988.setIcon(div_icon_b96cd533163cb1d1105100499b5fe0a5);
#
#
#             var marker_bb0c357bec58bc807e3e4e5f54c31134 = L.marker(
#                 [34.4098, -119.8587],
#                 {}
#             ).addTo(map_330cef23b271b6564d6d3ed827810ad9);
#
#
#             var div_icon_14a1d727a2d4f3c458ff18befd52aadc = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n                \u003cdiv style=\&quot;font-size: 18px; color: blue; font-weight: bold;\&quot;\u003e\n                    1\n                \u003c/div\u003e\n            &quot;});
#             marker_bb0c357bec58bc807e3e4e5f54c31134.setIcon(div_icon_14a1d727a2d4f3c458ff18befd52aadc);
#
#
#             var marker_94d156769272ae964c7e7a3ddf5774c0 = L.marker(
#                 [34.4174, -119.8606],
#                 {}
#             ).addTo(map_330cef23b271b6564d6d3ed827810ad9);
#
#
#             var div_icon_be6d4b59f0bc7da1f899ef126a1ead2e = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n                \u003cdiv style=\&quot;font-size: 18px; color: blue; font-weight: bold;\&quot;\u003e\n                    1\n                \u003c/div\u003e\n            &quot;});
#             marker_94d156769272ae964c7e7a3ddf5774c0.setIcon(div_icon_be6d4b59f0bc7da1f899ef126a1ead2e);
#
#
#             var marker_70ad71aec7b32ef1983c54a23f3f3d85 = L.marker(
#                 [34.41, -119.86],
#                 {}
#             ).addTo(map_330cef23b271b6564d6d3ed827810ad9);
#
#
#             var div_icon_7c876e1163b933cc3c90f0396369edbc = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n                \u003cdiv style=\&quot;font-size: 18px; color: blue; font-weight: bold;\&quot;\u003e\n                    1\n                \u003c/div\u003e\n            &quot;});
#             marker_70ad71aec7b32ef1983c54a23f3f3d85.setIcon(div_icon_7c876e1163b933cc3c90f0396369edbc);
#
#
#             var marker_37e12120c3799122862d25aab849da9d = L.marker(
#                 [34.41, -119.866],
#                 {}
#             ).addTo(map_330cef23b271b6564d6d3ed827810ad9);
#
#
#             var div_icon_aebe2f81037116811087cece8ad635e5 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n                \u003cdiv style=\&quot;font-size: 18px; color: blue; font-weight: bold;\&quot;\u003e\n                    1\n                \u003c/div\u003e\n            &quot;});
#             marker_37e12120c3799122862d25aab849da9d.setIcon(div_icon_aebe2f81037116811087cece8ad635e5);
#
#
#             var marker_fcd9de03ceb86b8f31f7b50a920d2a47 = L.marker(
#                 [34.4151, -119.8554],
#                 {}
#             ).addTo(map_330cef23b271b6564d6d

# %% [markdown]
# ## Trial 2 Conclusion

# %% [markdown]
# The heatmaps displayed the arrest counts for each location, but they were not visually appealing because some counts overlapped, creating a cluttered appearance, especially when zoomed out. To address this, I decided to take a different approach that improves visual clarity by adjusting the counts dynamically when zooming out. I will conduct another trial to implement this improvement.
